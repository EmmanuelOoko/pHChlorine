# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmanuelOoko/pHChlorine/blob/main/chlorine_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as plt
import matplotlib.pyplot as plt
from matplotlib import image as img
import cv2 as cv
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # **Free Chlorine 1.0 Manipulation**

# %%
fcl_1b = pd.read_csv("/content/drive/MyDrive/4.2/IS_2/chlorine_csv/cl1.0_rgb.csv")
fcl_1v = pd.read_csv("/content/drive/MyDrive/4.2/IS_2/chlorine_csv/cl1.0_hsv.csv")

# %%
fcl_1b.drop(['Unnamed: 0', 'chlorine'],  axis=1, inplace=True)
fcl_1b.drop(fcl_1b.index[1200:], inplace=True)

# %%
fcl_1v.drop(['Unnamed: 0'],  axis=1, inplace=True)
fcl_1v.rename(columns={'lumination':'value'}, inplace=True)
fcl_1v.drop(fcl_1v.index[1200:], inplace=True)

# %%
fcl1 = pd.DataFrame()
fcl1 = pd.concat([fcl_1b, fcl_1v], axis=1)
#fcl1.to_csv('/content/chlorine_data/fcl1.csv')
fcl1
# Out:
#            red      blue     green        hue  saturation     value  chlorine
# 0     0.541176  0.556863  0.564706  200.00020    0.041667  0.564706       1.0
# 1     0.533333  0.549020  0.552941  192.00029    0.035461  0.552941       1.0
# 2     0.533333  0.549020  0.552941  192.00029    0.035461  0.552941       1.0
# 3     0.533333  0.549020  0.552941  192.00029    0.035461  0.552941       1.0
# 4     0.525490  0.541176  0.549020  200.00020    0.042857  0.549020       1.0
# ...        ...       ...       ...        ...         ...       ...       ...
# 1195  0.521569  0.537255  0.545098  200.00020    0.043165  0.545098       1.0
# 1196  0.517647  0.533333  0.541176  200.00020    0.043478  0.541176       1.0
# 1197  0.517647  0.533333  0.541176  200.00020    0.043478  0.541176       1.0
# 1198  0.521569  0.537255  0.545098  200.00020    0.043165  0.545098       1.0
# 1199  0.517647  0.533333  0.541176  200.00020    0.043478  0.541176       1.0
#
# [1200 rows x 7 columns]

# %% [markdown]
# # **Free Chlorine 3.0 Manipulation**

# %%
fcl_3b = pd.read_csv("/content/drive/MyDrive/4.2/IS_2/chlorine_csv/cl3.0_rgb.csv")
fcl_3v = pd.read_csv("/content/drive/MyDrive/4.2/IS_2/chlorine_csv/cl3.0_hsv.csv")

# %%
fcl_3b.drop(['Unnamed: 0', 'chlorine'],  axis=1, inplace=True)
fcl_3b.drop(fcl_3b.index[1200:], inplace=True)
fcl_3b
# Out:
#            red      blue     green
# 0     0.592157  0.541176  0.592157
# 1     0.592157  0.541176  0.592157
# 2     0.584314  0.529412  0.584314
# 3     0.584314  0.529412  0.584314
# 4     0.580392  0.525490  0.580392
# ...        ...       ...       ...
# 1195  0.541176  0.474510  0.572549
# 1196  0.541176  0.474510  0.572549
# 1197  0.541176  0.478431  0.560784
# 1198  0.541176  0.478431  0.560784
# 1199  0.549020  0.482353  0.564706
#
# [1200 rows x 3 columns]

# %%
fcl_3v.drop(['Unnamed: 0'],  axis=1, inplace=True)
fcl_3v.rename(columns={'lumination':'value'}, inplace=True)
fcl_3v.drop(fcl_3v.index[1200:], inplace=True)
fcl_3v
# Out:
#             hue  saturation     value  chlorine
# 0     300.00015    0.086093  0.592157       3.0
# 1     300.00015    0.086093  0.592157       3.0
# 2     300.00012    0.093960  0.584314       3.0
# 3     300.00012    0.093960  0.584314       3.0
# 4     300.00012    0.094595  0.580392       3.0
# ...         ...         ...       ...       ...
# 1195  280.79996    0.171233  0.572549       3.0
# 1196  280.79996    0.171233  0.572549       3.0
# 1197  285.71423    0.146853  0.560784       3.0
# 1198  285.71423    0.146853  0.560784       3.0
# 1199  288.57135    0.145833  0.564706       3.0
#
# [1200 rows x 4 columns]

# %%
fcl3 = pd.DataFrame()
fcl3 = pd.concat([fcl_3b, fcl_3v], axis=1)
#fcl3.to_csv('/content/chlorine_data/fcl3.csv')
fcl3
# Out:
#            red      blue     green        hue  saturation     value  chlorine
# 0     0.592157  0.541176  0.592157  300.00015    0.086093  0.592157       3.0
# 1     0.592157  0.541176  0.592157  300.00015    0.086093  0.592157       3.0
# 2     0.584314  0.529412  0.584314  300.00012    0.093960  0.584314       3.0
# 3     0.584314  0.529412  0.584314  300.00012    0.093960  0.584314       3.0
# 4     0.580392  0.525490  0.580392  300.00012    0.094595  0.580392       3.0
# ...        ...       ...       ...        ...         ...       ...       ...
# 1195  0.541176  0.474510  0.572549  280.79996    0.171233  0.572549       3.0
# 1196  0.541176  0.474510  0.572549  280.79996    0.171233  0.572549       3.0
# 1197  0.541176  0.478431  0.560784  285.71423    0.146853  0.560784       3.0
# 1198  0.541176  0.478431  0.560784  285.71423    0.146853  0.560784       3.0
# 1199  0.549020  0.482353  0.564706  288.57135    0.145833  0.564706       3.0
#
# [1200 rows x 7 columns]

# %% [markdown]
# # **Free Chlorine 1.5 Manipulation**

# %%
fcl_15b = pd.read_csv("/content/drive/MyDrive/4.2/IS_2/chlorine_csv/cl1.5_rgb.csv")
fcl_15v = pd.read_csv("/content/drive/MyDrive/4.2/IS_2/chlorine_csv/cl1.5_hsv.csv")

# %%
fcl_15b.drop(['Unnamed: 0', 'chlorine'],  axis=1, inplace=True)
fcl_15b.drop(fcl_15b.index[1200:], inplace=True)
#fcl_15b.describe()

# %%
fcl_15v.drop(['Unnamed: 0'],  axis=1, inplace=True)
fcl_15v.rename(columns={'lumination':'value'}, inplace=True)
fcl_15v.drop(fcl_15v.index[1200:], inplace=True)
#fcl_15v.describe()
#fcl_15v

# %%
fcl15 = pd.DataFrame()
fcl15 = pd.concat([fcl_15b, fcl_15v], axis=1)
#fcl15.to_csv('/content/chlorine_data/fcl1.5.csv')
fcl15
# Out:
#            red      blue     green        hue  saturation     value  chlorine
# 0     0.525490  0.486274  0.556863  273.33328    0.126761  0.556863       1.5
# 1     0.525490  0.486274  0.556863  273.33328    0.126761  0.556863       1.5
# 2     0.525490  0.486274  0.556863  273.33328    0.126761  0.556863       1.5
# 3     0.525490  0.486274  0.556863  273.33328    0.126761  0.556863       1.5
# 4     0.521569  0.482353  0.549020  275.29407    0.121429  0.549020       1.5
# ...        ...       ...       ...        ...         ...       ...       ...
# 1195  0.505882  0.462745  0.533333  276.66663    0.132353  0.533333       1.5
# 1196  0.513725  0.454902  0.529412  287.36835    0.140741  0.529412       1.5
# 1197  0.513725  0.454902  0.529412  287.36835    0.140741  0.529412       1.5
# 1198  0.513725  0.450980  0.533333  285.71423    0.154412  0.533333       1.5
# 1199  0.513725  0.450980  0.533333  285.71423    0.154412  0.533333       1.5
#
# [1200 rows x 7 columns]

# %% [markdown]
# # **Free Chlorine 0.6 Manipulation**

# %%
fcl_6b = pd.read_csv("/content/drive/MyDrive/4.2/IS_2/chlorine_csv/cl0.6_rgb.csv")
fcl_6v = pd.read_csv("/content/drive/MyDrive/4.2/IS_2/chlorine_csv/cl0.6_hsv.csv")

# %%
fcl_6b.drop(['Unnamed: 0', 'chlorine'],  axis=1, inplace=True)
fcl_6b.drop(fcl_6b.index[1200:], inplace=True)
#fcl_6b.describe()

# %%
fcl_6v.drop(['Unnamed: 0'],  axis=1, inplace=True)
fcl_6v.rename(columns={'lumination':'value'}, inplace=True)
fcl_6v.drop(fcl_6v.index[1200:], inplace=True)
#fcl_6v.describe()
fcl_6v
# Out:
#             hue  saturation     value  chlorine
# 0     214.28583    0.047945  0.572549       0.6
# 1     200.00020    0.041379  0.568627       0.6
# 2     200.00020    0.041667  0.564706       0.6
# 3     214.28583    0.047945  0.572549       0.6
# 4     214.28583    0.048276  0.568627       0.6
# ...         ...         ...       ...       ...
# 1195  214.28583    0.048611  0.564706       0.6
# 1196  214.28583    0.048951  0.560784       0.6
# 1197  214.28583    0.048951  0.560784       0.6
# 1198  214.28583    0.048951  0.560784       0.6
# 1199  169.99988    0.083916  0.560784       0.6
#
# [1200 rows x 4 columns]

# %%
fcl6 = pd.DataFrame()
fcl6 = pd.concat([fcl_6b, fcl_6v], axis=1)
#fcl6.to_csv('/content/chlorine_data/fcl0.6.csv')
fcl6
# Out:
#            red      blue     green        hue  saturation     value  chlorine
# 0     0.545098  0.556863  0.572549  214.28583    0.047945  0.572549       0.6
# 1     0.545098  0.560784  0.568627  200.00020    0.041379  0.568627       0.6
# 2     0.541176  0.556863  0.564706  200.00020    0.041667  0.564706       0.6
# 3     0.545098  0.556863  0.572549  214.28583    0.047945  0.572549       0.6
# 4     0.541176  0.552941  0.568627  214.28583    0.048276  0.568627       0.6
# ...        ...       ...       ...        ...         ...       ...       ...
# 1195  0.537255  0.549020  0.564706  214.28583    0.048611  0.564706       0.6
# 1196  0.533333  0.545098  0.560784  214.28583    0.048951  0.560784       0.6
# 1197  0.533333  0.545098  0.560784  214.28583    0.048951  0.560784       0.6
# 1198  0.533333  0.545098  0.560784  214.28583    0.048951  0.560784       0.6
# 1199  0.513725  0.560784  0.552941  169.99988    0.083916  0.560784       0.6
#
# [1200 rows x 7 columns]

# %% [markdown]
# # **Finalizing Chlorine Dataset**

# %%
matokeo = pd.DataFrame()
#matokeo = matokeo.reset_index(drop=True)
matokeo = pd.concat([fcl6, fcl3, fcl1, fcl15], ignore_index=True)
matokeo
# Out:
#            red      blue     green        hue  saturation     value  chlorine
# 0     0.545098  0.556863  0.572549  214.28583    0.047945  0.572549       0.6
# 1     0.545098  0.560784  0.568627  200.00020    0.041379  0.568627       0.6
# 2     0.541176  0.556863  0.564706  200.00020    0.041667  0.564706       0.6
# 3     0.545098  0.556863  0.572549  214.28583    0.047945  0.572549       0.6
# 4     0.541176  0.552941  0.568627  214.28583    0.048276  0.568627       0.6
# ...        ...       ...       ...        ...         ...       ...       ...
# 4795  0.505882  0.462745  0.533333  276.66663    0.132353  0.533333       1.5
# 4796  0.513725  0.454902  0.529412  287.36835    0.140741  0.529412       1.5
# 4797  0.513725  0.454902  0.529412  287.36835    0.140741  0.529412       1.5
# 4798  0.513725  0.450980  0.533333  285.71423    0.154412  0.533333       1.5
# 4799  0.513725  0.450980  0.533333  285.71423    0.154412  0.533333       1.5
#
# [4800 rows x 7 columns]

# %%
matokeo.to_csv('/content/drive/MyDrive/4.2/IS_2/datasets/fcl_dataset.csv')

# %% [markdown]
# # **Working on the free Chlorine Dataset**

# %%
dataset = pd.read_csv('/content/drive/MyDrive/4.2/IS_2/datasets/fcl_dataset.csv')
dataset
# Out:
#       Unnamed: 0       red      blue     green        hue  saturation  \
# 0              0  0.545098  0.556863  0.572549  214.28583    0.047945
# 1              1  0.545098  0.560784  0.568627  200.00020    0.041379
# 2              2  0.541176  0.556863  0.564706  200.00020    0.041667
# 3              3  0.545098  0.556863  0.572549  214.28583    0.047945
# 4              4  0.541176  0.552941  0.568627  214.28583    0.048276
# ...          ...       ...       ...       ...        ...         ...
# 4795        4795  0.505882  0.462745  0.533333  276.66663    0.132353
# 4796        4796  0.513725  0.454902  0.529412  287.36835    0.140741
# 4797        4797  0.513725  0.454902  0.529412  287.36835    0.140741
# 4798        4798  0.513725  0.450980  0.533333  285.71423    0.154412
# 4799        4799  0.513725  0.450980  0.533333  285.71423    0.154412
#
#          value  chlorine
# 0     0.572549       0.6
# 1     0.568627       0.6
# 2     0.564706       0.6
# ...

# %%
dataset.drop(['Unnamed: 0', 'red', 'blue', 'green'], axis=1, inplace=True) #Dropping the RGB Values and Unnamed column
dataset = dataset.sample(frac = 1) # shuffle the DataFrame rows
dataset.tail(4)
# Out:
#             hue  saturation     value  chlorine
# 257   185.00014    0.083333  0.564706       0.6
# 1677  290.52625    0.132867  0.560784       3.0
# 3213  187.50020    0.057143  0.549020       1.0
# 4134  281.53836    0.095588  0.533333       1.5

# %%
# One-Hot-Encoding
dataset = pd.get_dummies(dataset, columns=['chlorine'])
dataset.head()
# Out:
#             hue  saturation     value  chlorine_0.6  chlorine_1.0  \
# 71    192.00029    0.035211  0.556863             1             0
# 696   200.00014    0.062069  0.568627             1             0
# 3045  200.00020    0.043165  0.545098             0             1
# 4739  289.09080    0.079710  0.541176             0             0
# 4525  273.33325    0.133333  0.529412             0             0
#
#       chlorine_1.5  chlorine_3.0
# 71               0             0
# 696              0             0
# 3045             0             0
# 4739             1             0
# 4525             1             0

# %% [markdown]
# # **Split the data into train and test set**

# %%
train_dataset = dataset.sample(frac=0.8, random_state=8) #train_dataset = 80% of total dataset  
#random_state = any int value means every time when you run your program you will get the same output for train and test dataset, random_state is None by default which means every time when you run your program you will get different output because of splitting between train and test varies within 
test_dataset = dataset.drop(train_dataset.index) #remove train_dataset from dataframe to get test_dataset
train_dataset
# Out:
#             hue  saturation     value  chlorine_0.6  chlorine_1.0  \
# 1608  269.99990    0.082759  0.568627             0             0
# 4634  279.99988    0.091603  0.513725             0             0
# 449   195.00017    0.055556  0.564706             1             0
# 1803  276.66663    0.124138  0.568627             0             0
# 1914  275.99988    0.068493  0.572549             0             0
# ...         ...         ...       ...           ...           ...
# 169   195.00017    0.055556  0.564706             1             0
# 3941  266.66660    0.133333  0.529412             0             0
# 3784  279.99988    0.091603  0.513725             0             0
# 4438  283.63626    0.080292  0.537255             0             0
# 4096  279.99988    0.091603  0.513725             0             0
#
#       chlorine_1.5  chlorine_3.0
# 1608             0             1
# 4634             1             0
# 449              0             0
# 1803             0             1
# ...

# %%
test_dataset
# Out:
#             hue  saturation     value  chlorine_0.6  chlorine_1.0  \
# 2879  204.00010    0.070922  0.552941             0             1
# 4786  273.33325    0.133333  0.529412             0             0
# 1623  275.99988    0.068965  0.568627             0             0
# 854   171.42834    0.049296  0.556863             1             0
# 3777  272.30760    0.097744  0.521569             0             0
# ...         ...         ...       ...           ...           ...
# 3774  272.30762    0.096296  0.529412             0             0
# 1561  287.36835    0.133803  0.556863             0             0
# 1067  214.28583    0.048276  0.568627             1             0
# 4607  269.99994    0.086957  0.541176             0             0
# 3213  187.50020    0.057143  0.549020             0             1
#
#       chlorine_1.5  chlorine_3.0
# 2879             0             0
# 4786             1             0
# 1623             0             1
# 854              0             0
# ...

# %% [markdown]
# # **Split input features and output labels**

# %%
train_labels = pd.DataFrame([train_dataset.pop(x) for x in ['chlorine_0.6',	'chlorine_1.0',	'chlorine_1.5',	'chlorine_3.0']]).T
train_dataset
# Out:
#             hue  saturation     value
# 1608  269.99990    0.082759  0.568627
# 4634  279.99988    0.091603  0.513725
# 449   195.00017    0.055556  0.564706
# 1803  276.66663    0.124138  0.568627
# 1914  275.99988    0.068493  0.572549
# ...         ...         ...       ...
# 169   195.00017    0.055556  0.564706
# 3941  266.66660    0.133333  0.529412
# 3784  279.99988    0.091603  0.513725
# 4438  283.63626    0.080292  0.537255
# 4096  279.99988    0.091603  0.513725
#
# [3840 rows x 3 columns]

# %%
#Splitting for test dataset
test_labels = pd.DataFrame([test_dataset.pop(x) for x in ['chlorine_0.6',	'chlorine_1.0',	'chlorine_1.5',	'chlorine_3.0']]).T
test_dataset
# Out:
#             hue  saturation     value
# 2879  204.00010    0.070922  0.552941
# 4786  273.33325    0.133333  0.529412
# 1623  275.99988    0.068965  0.568627
# 854   171.42834    0.049296  0.556863
# 3777  272.30760    0.097744  0.521569
# ...         ...         ...       ...
# 3774  272.30762    0.096296  0.529412
# 1561  287.36835    0.133803  0.556863
# 1067  214.28583    0.048276  0.568627
# 4607  269.99994    0.086957  0.541176
# 3213  187.50020    0.057143  0.549020
#
# [960 rows x 3 columns]

# %% [markdown]
# # **Build & Compile the Model**

# %%
# Importing Tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
print(tf.__version__)
# Out:
# 2.9.2

# %%
# !pip install git+https://github.com/tensorflow/docs # Use some functions from tensorflow_docs
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/tensorflow/docs to /tmp/pip-req-build-47lbm12a
#   Running command git clone -q https://github.com/tensorflow/docs /tmp/pip-req-build-47lbm12a
# ...
#   Created wheel for tensorflow-docs: filename=tensorflow_docs-0.0.0.dev0-py3-none-any.whl size=184468 sha256=3c7a6745ed7cc47534cbcc4652c1ab7d0a03f4e402d3bad3f089556bca780246
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ly7yr1i1/wheels/3b/ee/a2/ab4d36a9a4af495bcb936f3e849d4b497b65fa40548a68d6c3
# Successfully built tensorflow-docs
# ...

# %%
from keras import regularizers #regularizers performs regularization which is used to reduce Overfitting 
from keras.utils import to_categorical

model = keras.Sequential([
    layers.Dense(3, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=[len(train_dataset.keys())]), #inputshape=[3]
    layers.Dense(24, kernel_regularizer=regularizers.l2(0.001), activation='relu'),
    layers.Dense(24, kernel_regularizer=regularizers.l2(0.001), activation='relu'),
    layers.Dense(16, kernel_regularizer=regularizers.l2(0.001), activation='relu'),
    layers.Dense(4)
  ])

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.001)
loss_function = tf.keras.losses.CategoricalCrossentropy(from_logits=True)

model.compile(loss=loss_function , #loss=loss_function 
                optimizer=optimizer,
                metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 3)                 12
#
#  dense_1 (Dense)             (None, 24)                96
#
#  dense_2 (Dense)             (None, 24)                600
#
#  dense_3 (Dense)             (None, 16)                400
#
#  dense_4 (Dense)             (None, 4)                 68
#
# ...
# Total params: 1,176
# Trainable params: 1,176
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Train the Model**

# %%
train_labels
# Out:
#       chlorine_0.6  chlorine_1.0  chlorine_1.5  chlorine_3.0
# 1608             0             0             0             1
# 4634             0             0             1             0
# 449              1             0             0             0
# 1803             0             0             0             1
# 1914             0             0             0             1
# ...            ...           ...           ...           ...
# 169              1             0             0             0
# 3941             0             0             1             0
# 3784             0             0             1             0
# 4438             0             0             1             0
# 4096             0             0             1             0
#
# [3840 rows x 4 columns]

# %%
print(len(train_dataset)) 
print(len(train_labels))
# Out:
# 3840
# 3840

# %%
history = model.fit( x=train_dataset, y=train_labels, validation_split=0.2, 
                    epochs=7001, batch_size=2048, verbose=0, 
                    callbacks=[tfdocs.modeling.EpochDots()], shuffle=True)
# Out:
# Epoch: 0, accuracy:0.2458,  loss:24.4962,  val_accuracy:0.2630,  val_loss:22.1826,
# ....................................................................................................
# Epoch: 100, accuracy:0.2601,  loss:1.3894,  val_accuracy:0.2487,  val_loss:1.3906,
# ....................................................................................................
# Epoch: 200, accuracy:0.4329,  loss:1.2563,  val_accuracy:0.4323,  val_loss:1.2590,
# ....................................................................................................
# Epoch: 300, accuracy:0.5075,  loss:1.0753,  val_accuracy:0.4792,  val_loss:1.0780,
# ....................................................................................................
# Epoch: 400, accuracy:0.4899,  loss:0.8177,  val_accuracy:0.4688,  val_loss:0.8259,
# ....................................................................................................
# ...

# %%
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
plotter.plot({'Basic': history}, metric = "accuracy")
plt.ylim([0, 1])
plt.ylabel('accuracy [Free Chlorine]')
# Out:
# Text(0, 0.5, 'accuracy [Free Chlorine]')

# %%
plotter.plot({'Basic': history}, metric = "loss")
plt.ylim([0, 4])
plt.ylabel('loss [Free Chlorine]')
# Out:
# Text(0, 0.5, 'loss [Free Chlorine]')

# %% [markdown]
# # **Making Prediction for Test Dataset from the trained model**

# %%
test_predictions = model.predict(test_dataset)
print("shape is {}".format(test_predictions.shape))  
test_predictions
# Out:
# 30/30 [==============================] - 0s 3ms/step
# shape is (960, 4)
# array([[  9.830922  ,   9.898714  ,  -9.9494505 , -16.911095  ],
#        [ -2.4371705 ,  -0.15571803,   3.737621  ,   2.5814624 ],
#        [ -2.6253576 ,  -0.2940852 ,   3.9577172 ,   2.8592725 ],
#        ...,
#        [  8.17124   ,   8.514464  ,  -8.080549  , -14.240453  ],
#        [ -1.6235366 ,   0.5159195 ,   2.8405807 ,   1.2825999 ],
#        [ 12.719529  ,  12.325399  , -13.194572  , -21.582722  ]],
#       dtype=float32)

# %%
test_predictions[0]
# Out:
# array([  9.830922 ,   9.898714 ,  -9.9494505, -16.911095 ], dtype=float32)

# %%
#Selecting Class with highest confidence
predicted_encoded_test_labels = np.argmax(test_predictions, axis=1) #Returns the indices of the maximum values along each row(axis=1)
#Converting numpy array to pandas dataframe
predicted_encoded_test_labels = pd.DataFrame(predicted_encoded_test_labels, columns=['Predicted Labels'])
predicted_encoded_test_labels
# Out:
#      Predicted Labels
# 0                   1
# 1                   2
# 2                   2
# 3                   0
# 4                   2
# ..                ...
# 955                 2
# 956                 3
# 957                 1
# 958                 2
# 959                 0
#
# [960 rows x 1 columns]

# %%
#Converting One-Hot Encoded Actual Test set labels into Label Encoding format
actual_encoded_test_labels = np.argmax(test_labels.to_numpy(), axis=1) 
#Converting numpy array to pandas dataframe
actual_encoded_test_labels = pd.DataFrame(actual_encoded_test_labels, columns=['Actual Labels'])
actual_encoded_test_labels
# Out:
#      Actual Labels
# 0                1
# 1                2
# 2                3
# 3                0
# 4                2
# ..             ...
# 955              2
# 956              3
# 957              0
# 958              2
# 959              1
#
# [960 rows x 1 columns]

# %% [markdown]
# # **Evaluate Model Performance**

# %%
model.evaluate(x=test_dataset, y=test_labels)
# Out:
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6376 - accuracy: 0.6490
# [0.6375669240951538, 0.6489583253860474]

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

confusion_matrix_test = confusion_matrix(actual_encoded_test_labels, predicted_encoded_test_labels)
f,ax = plt.subplots(figsize=(16,12))
categories = ['chlorine_0.6',	'chlorine_1.0',	'chlorine_1.5',	'chlorine_3.0']
sns.heatmap(confusion_matrix_test, annot=True, cmap='Blues', fmt='d',
            xticklabels = categories,
            yticklabels = categories)
plt.show()

# %% [markdown]
# # **Classification Report**

# %%
#Classification Report
target_names = ['chlorine_0.6',	'chlorine_1.0',	'chlorine_1.5',	'chlorine_3.0']
print(classification_report(actual_encoded_test_labels, predicted_encoded_test_labels, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
# chlorine_0.6       0.53      0.64      0.58       244
# chlorine_1.0       0.52      0.39      0.44       243
# chlorine_1.5       0.72      0.95      0.82       253
# chlorine_3.0       0.92      0.60      0.72       220
#
#     accuracy                           0.65       960
#    macro avg       0.67      0.64      0.64       960
# weighted avg       0.66      0.65      0.64       960

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
from keras.models import model_from_json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Save the entire model to an HDF5 file.
# The '.h5' extension indicates that the model is saved to HDF5.
model.save('/content/drive/MyDrive/4.2/IS_2/cl_model/cl_model.h5') 
#Download trained model using Colab
#from google.colab import files
#files.download("ph_model_trained.h5")

# %%
# serialize model to json
json_model = model.to_json()

#save the model architecture to JSON file
with open('/content/drive/MyDrive/4.2/IS_2/cl_model/cl_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/MyDrive/4.2/IS_2/cl_model/cl_model_weights.h5')
#Model loss and accuracy
#loss,acc = model.evaluate(test_labels, verbose=2)
